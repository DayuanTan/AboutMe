# %% [markdown]
# # softmax回归的简洁实现
# :label:`sec_softmax_concise`
#
# 在 :numref:`sec_linear_concise`中，
# 我们发现(**通过深度学习框架的高级API能够使实现**)
# (~~softmax~~)
# 线性(**回归变得更加容易**)。
# 同样，通过深度学习框架的高级API也能更方便地实现softmax回归模型。
# 本节如在 :numref:`sec_softmax_scratch`中一样，
# 继续使用Fashion-MNIST数据集，并保持批量大小为256。

# %%
# !pip install d2l
import torch
from torch import nn
from d2l import torch as d2l

# %matplotlib inline
d2l.use_svg_display() # Display clearly
from IPython import display
# Out:
# Requirement already satisfied: d2l in /Users/dyt/miniconda3/lib/python3.11/site-packages (1.0.3)
# Requirement already satisfied: jupyter==1.0.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from d2l) (1.0.0)
# Requirement already satisfied: numpy==1.23.5 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from d2l) (1.23.5)
# Requirement already satisfied: matplotlib==3.7.2 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from d2l) (3.7.2)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from d2l) (0.1.6)
# Requirement already satisfied: requests==2.31.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from d2l) (2.31.0)
# Requirement already satisfied: pandas==2.0.3 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from d2l) (2.0.3)
# Requirement already satisfied: scipy==1.10.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from d2l) (1.10.1)
# Requirement already satisfied: notebook in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter==1.0.0->d2l) (7.0.6)
# Requirement already satisfied: qtconsole in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter==1.0.0->d2l) (5.5.1)
# Requirement already satisfied: jupyter-console in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter==1.0.0->d2l) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter==1.0.0->d2l) (7.11.0)
# Requirement already satisfied: ipykernel in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter==1.0.0->d2l) (6.27.1)
# Requirement already satisfied: ipywidgets in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter==1.0.0->d2l) (8.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from matplotlib==3.7.2->d2l) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from matplotlib==3.7.2->d2l) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from matplotlib==3.7.2->d2l) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from matplotlib==3.7.2->d2l) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from matplotlib==3.7.2->d2l) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from matplotlib==3.7.2->d2l) (10.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from matplotlib==3.7.2->d2l) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from matplotlib==3.7.2->d2l) (2.8.2)
# Requirement already satisfied: traitlets in /Users/dyt/miniconda3/lib/python3.11/site-packages (from matplotlib-inline==0.1.6->d2l) (5.14.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from pandas==2.0.3->d2l) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from pandas==2.0.3->d2l) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from requests==2.31.0->d2l) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from requests==2.31.0->d2l) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from requests==2.31.0->d2l) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from requests==2.31.0->d2l) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib==3.7.2->d2l) (1.16.0)
# Requirement already satisfied: appnope in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->d2l) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->d2l) (0.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->d2l) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->d2l) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.5.0)
# Requirement already satisfied: nest-asyncio in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.5.8)
# Requirement already satisfied: psutil in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.9.6)
# Requirement already satisfied: pyzmq>=20 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->d2l) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyter==1.0.0->d2l) (6.4)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipywidgets->jupyter==1.0.0->d2l) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipywidgets->jupyter==1.0.0->d2l) (3.0.9)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-console->jupyter==1.0.0->d2l) (3.0.41)
# Requirement already satisfied: pygments in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-console->jupyter==1.0.0->d2l) (2.17.2)
# Requirement already satisfied: beautifulsoup4 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0->d2l) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0->d2l) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/dyt/miniconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0->d2l) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in /Users/dyt/miniconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0->d2l) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0->d2l) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.9.0)
# Requirement already satisfied: nbformat>=5.7 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0->d2l) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0->d2l) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from nbconvert->jupyter==1.0.0->d2l) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from notebook->jupyter==1.0.0->d2l) (2.11.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from notebook->jupyter==1.0.0->d2l) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from notebook->jupyter==1.0.0->d2l) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from notebook->jupyter==1.0.0->d2l) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from qtconsole->jupyter==1.0.0->d2l) (2.4.1)
# Requirement already satisfied: webencodings in /Users/dyt/miniconda3/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert->jupyter==1.0.0->d2l) (0.5.1)
# Requirement already satisfied: decorator in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.19.1)
# Requirement already satisfied: stack-data in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->d2l) (4.0.0)
# Requirement already satisfied: anyio>=3.1.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (4.1.0)
# Requirement already satisfied: argon2-cffi in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.4.4)
# Requirement already satisfied: overrides in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (7.4.0)
# Requirement already satisfied: prometheus-client in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.19.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.18.0)
# Requirement already satisfied: websocket-client in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter==1.0.0->d2l) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter==1.0.0->d2l) (2.2.1)
# Requirement already satisfied: babel>=2.10 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (4.20.0)
# Requirement already satisfied: fastjsonschema in /Users/dyt/miniconda3/lib/python3.11/site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->d2l) (2.19.0)
# Requirement already satisfied: wcwidth in /Users/dyt/miniconda3/lib/python3.11/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0->d2l) (0.2.12)
# Requirement already satisfied: soupsieve>1.2 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->d2l) (2.5)
# Requirement already satisfied: sniffio>=1.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (0.13.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/dyt/miniconda3/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/dyt/miniconda3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.2.2)
# Requirement already satisfied: fqdn in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.5.1)
# Requirement already satisfied: isoduration in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.1)
# Requirement already satisfied: uri-template in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.15.1)
# Requirement already satisfied: pycparser in /Users/dyt/miniconda3/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/dyt/miniconda3/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.8.19.14)

# %%
batch_size = 256
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size)

# %% [markdown]
# ## 初始化模型参数
#
# 如我们在 :numref:`sec_softmax`所述，
# [**softmax回归的输出层是一个全连接层**]。
# 因此，为了实现我们的模型，
# 我们只需在`Sequential`中添加一个带有10个输出的全连接层。
# 同样，在这里`Sequential`并不是必要的，
# 但它是实现深度模型的基础。
# 我们仍然以均值0和标准差0.01随机初始化权重。

# %%
# PyTorch不会隐式地调整输入的形状。因此，
# 我们在线性层前定义了展平层（flatten），来调整网络输入的形状
net = nn.Sequential(nn.Flatten(), nn.Linear(784, 10))

def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.01)

net.apply(init_weights);

# %% [markdown]
# ## 重新审视Softmax的实现
# :label:`subsec_softmax-implementation-revisited`
#
# 在前面 :numref:`sec_softmax_scratch`的例子中，
# 我们计算了模型的输出，然后将此输出送入交叉熵损失。
# 从数学上讲，这是一件完全合理的事情。
# 然而，从计算角度来看，指数可能会造成数值稳定性问题。
#
# 回想一下，softmax函数$\hat y_j = \frac{\exp(o_j)}{\sum_k \exp(o_k)}$，
# 其中$\hat y_j$是预测的概率分布。
# $o_j$是未规范化的预测$\mathbf{o}$的第$j$个元素。
# 如果$o_k$中的一些数值非常大，
# 那么$\exp(o_k)$可能大于数据类型容许的最大数字，即*上溢*（overflow）。
# 这将使分母或分子变为`inf`（无穷大），
# 最后得到的是0、`inf`或`nan`（不是数字）的$\hat y_j$。
# 在这些情况下，我们无法得到一个明确定义的交叉熵值。
#
# 解决这个问题的一个技巧是：
# 在继续softmax计算之前，先从所有$o_k$中减去$\max(o_k)$。
# 这里可以看到每个$o_k$按常数进行的移动不会改变softmax的返回值：
#
# $$
# \begin{aligned}
# \hat y_j & =  \frac{\exp(o_j - \max(o_k))\exp(\max(o_k))}{\sum_k \exp(o_k - \max(o_k))\exp(\max(o_k))} \\
# & = \frac{\exp(o_j - \max(o_k))}{\sum_k \exp(o_k - \max(o_k))}.
# \end{aligned}
# $$
#
#
# 在减法和规范化步骤之后，可能有些$o_j - \max(o_k)$具有较大的负值。
# 由于精度受限，$\exp(o_j - \max(o_k))$将有接近零的值，即*下溢*（underflow）。
# 这些值可能会四舍五入为零，使$\hat y_j$为零，
# 并且使得$\log(\hat y_j)$的值为`-inf`。
# 反向传播几步后，我们可能会发现自己面对一屏幕可怕的`nan`结果。
#
# 尽管我们要计算指数函数，但我们最终在计算交叉熵损失时会取它们的对数。
# 通过将softmax和交叉熵结合在一起，可以避免反向传播过程中可能会困扰我们的数值稳定性问题。
# 如下面的等式所示，我们避免计算$\exp(o_j - \max(o_k))$，
# 而可以直接使用$o_j - \max(o_k)$，因为$\log(\exp(\cdot))$被抵消了。
#
# $$
# \begin{aligned}
# \log{(\hat y_j)} & = \log\left( \frac{\exp(o_j - \max(o_k))}{\sum_k \exp(o_k - \max(o_k))}\right) \\
# & = \log{(\exp(o_j - \max(o_k)))}-\log{\left( \sum_k \exp(o_k - \max(o_k)) \right)} \\
# & = o_j - \max(o_k) -\log{\left( \sum_k \exp(o_k - \max(o_k)) \right)}.
# \end{aligned}
# $$
#
# 我们也希望保留传统的softmax函数，以备我们需要评估通过模型输出的概率。
# 但是，我们没有将softmax概率传递到损失函数中，
# 而是[**在交叉熵损失函数中传递未规范化的预测，并同时计算softmax及其对数**]，
# 这是一种类似["LogSumExp技巧"](https://en.wikipedia.org/wiki/LogSumExp)的聪明方式。

# %%
loss = nn.CrossEntropyLoss(reduction='none')

# %% [markdown]
# ## 优化算法
#
# 在这里，我们(**使用学习率为0.1的小批量随机梯度下降作为优化算法**)。
# 这与我们在线性回归例子中的相同，这说明了优化器的普适性。

# %%
trainer = torch.optim.SGD(net.parameters(), lr=0.1)

# %% [markdown]
# ## 训练
#
# 接下来我们[**调用**] :numref:`sec_softmax_scratch`中(~~之前~~)
# (**定义的训练函数来训练模型**)。

# %%
def accuracy(y_hat, y):  #@save
    """计算预测正确的数量"""
    if len(y_hat.shape) > 1 and y_hat.shape[1] > 1:
        y_hat = y_hat.argmax(axis=1)
    cmp = y_hat.type(y.dtype) == y
    return float(cmp.type(y.dtype).sum())

def evaluate_accuracy(net, data_iter):  #@save
    """计算在指定数据集上模型的精度"""
    if isinstance(net, torch.nn.Module):
        net.eval()  # 将模型设置为评估模式
    metric = Accumulator(2)  # 正确预测数、预测总数
    with torch.no_grad():
        for X, y in data_iter:
            metric.add(accuracy(net(X), y), y.numel())
    return metric[0] / metric[1]
    
class Accumulator:  #@save
    """在n个变量上累加"""
    def __init__(self, n):
        self.data = [0.0] * n

    def add(self, *args):
        self.data = [a + float(b) for a, b in zip(self.data, args)]

    def reset(self):
        self.data = [0.0] * len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]
        
def train_epoch_ch3(net, train_iter, loss, updater):  #@save
    """训练模型一个迭代周期（定义见第3章）"""
    # 将模型设置为训练模式
    if isinstance(net, torch.nn.Module): #如果用了nn的module；这里没用，但是加上这个方便后面复用这个代码
        net.train()
    # 训练损失总和、训练准确度总和、样本数
    metric = Accumulator(3)
    for X, y in train_iter:#扫一遍数据
        # 计算梯度并更新参数
        y_hat = net(X)
        l = loss(y_hat, y) #使用传入的loss；后面调用时穿了cross_entropy
        if isinstance(updater, torch.optim.Optimizer):#如果updater是optim的Optimizer的话。实际后面调用时用的sgd
            # 使用PyTorch内置的优化器和损失函数
            updater.zero_grad()
            l.mean().backward()
            updater.step()
        else:#如果使用的是自己实现的。实际后面调用时用的是自己实现的sgd
            # 使用定制的优化器和损失函数
            l.sum().backward()
            updater(X.shape[0])
        metric.add(float(l.sum()), accuracy(y_hat, y), y.numel())
    # 返回训练损失和训练精度
    return metric[0] / metric[2], metric[1] / metric[2]
    
class Animator:  #@save
    """在动画中绘制数据"""
    def __init__(self, xlabel=None, ylabel=None, legend=None, xlim=None,
                 ylim=None, xscale='linear', yscale='linear',
                 fmts=('-', 'm--', 'g-.', 'r:'), nrows=1, ncols=1,
                 figsize=(3.5, 2.5)):
        # 增量地绘制多条线
        if legend is None:
            legend = []
        d2l.use_svg_display()
        self.fig, self.axes = d2l.plt.subplots(nrows, ncols, figsize=figsize)
        if nrows * ncols == 1:
            self.axes = [self.axes, ]
        # 使用lambda函数捕获参数
        self.config_axes = lambda: d2l.set_axes(
            self.axes[0], xlabel, ylabel, xlim, ylim, xscale, yscale, legend)
        self.X, self.Y, self.fmts = None, None, fmts

    def add(self, x, y):
        # 向图表中添加多个数据点
        if not hasattr(y, "__len__"):
            y = [y]
        n = len(y)
        if not hasattr(x, "__len__"):
            x = [x] * n
        if not self.X:
            self.X = [[] for _ in range(n)]
        if not self.Y:
            self.Y = [[] for _ in range(n)]
        for i, (a, b) in enumerate(zip(x, y)):
            if a is not None and b is not None:
                self.X[i].append(a)
                self.Y[i].append(b)
        self.axes[0].cla()
        for x, y, fmt in zip(self.X, self.Y, self.fmts):
            self.axes[0].plot(x, y, fmt)
        self.config_axes()
        display.display(self.fig)
        display.clear_output(wait=True)
        
def train_ch3(net, train_iter, test_iter, loss, num_epochs, updater):  #@save #ch3就是第三章
    """训练模型（定义见第3章）"""
    animator = Animator(xlabel='epoch', xlim=[1, num_epochs], ylim=[0.3, 0.9],
                        legend=['train loss', 'train acc', 'test acc'])
    for epoch in range(num_epochs):
        train_metrics = train_epoch_ch3(net, train_iter, loss, updater)
        test_acc = evaluate_accuracy(net, test_iter)
        animator.add(epoch + 1, train_metrics + (test_acc,))
    train_loss, train_acc = train_metrics
    assert train_loss < 0.5, train_loss
    assert train_acc <= 1 and train_acc > 0.7, train_acc
    assert test_acc <= 1 and test_acc > 0.7, test_acc

# %%
num_epochs = 10
#d2l.train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)
train_ch3(net, train_iter, test_iter, loss, num_epochs, trainer)

# %% [markdown]
# 和以前一样，这个算法使结果收敛到一个相当高的精度，而且这次的代码比之前更精简了。
#
# ## 小结
#
# * 使用深度学习框架的高级API，我们可以更简洁地实现softmax回归。
# * 从计算的角度来看，实现softmax回归比较复杂。在许多情况下，深度学习框架在这些著名的技巧之外采取了额外的预防措施，来确保数值的稳定性。这使我们避免了在实践中从零开始编写模型时可能遇到的陷阱。
